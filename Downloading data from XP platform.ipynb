# %% [markdown]
# ### Downloading data from XP platform
#
# Markos Flavio B. G. O.
#
# __Context: Web scraping.__
#
# In this notebook fund's context and historical information will be scrapped from data available at https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx and saved in a pickle file.
#
# __Specific objectives__
#
#      1. Download and save all useful information from funds at https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx in a pickle file.
#
# __Status: Further work__
#     - Include a function that updates and automatically includes new data into the existing data base.
#     - Add parallelism.

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import pickle
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import json
import datetime
from sys import getsizeof
import pprint

# %% [markdown]
# The scraping strategy has two main parts:
#     1. Gathering surface information from each fund at the main page of funds and saving them in a dictionary.
#     2. Scanning each individual link and scraping deep information, including all historical data, and feeding them into the dictionaries.

# %% [markdown]
# #### 1. Gathering surface data

# %% [markdown]
# The surface data is enough for updating existing information. Thus, one may not scan the individual pages for updates. Some funds don't have historical data available. These are the ones with the 'Rent mês' attribute equals N/D or 'Não há'. That's the purpose of the 'Info' attribute.

# %%
main_page = 'https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx'

# %%
def surf_data(num_rows=''):
    """
    It scraps surface data from funds available at the link below and saves them as a pickle file.
    https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx

    Parameters
    ----------
    num_rows : int
        Number of funds to be scraped. If empty, all rows will be scanned.
    
    Returns
    -------
    df_surf : pandas.DataFrame
        Surface data.
    
    """ 
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    options.add_argument("safebrowsing-disable-extension-blacklist")
    driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver.exe')
    driver.get('https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx')

    if num_rows:
        rows = driver.find_elements_by_xpath("//table[@id='tableTodos']/tbody/tr")[:num_rows]
    else:
        rows = driver.find_elements_by_xpath("//table[@id='tableTodos']/tbody/tr")
   
    total_rows = len(rows)
    funds = []
    start_time = time.time()
    for i, row in enumerate(rows):
        d = {}
        d['Risco'] = row.find_element_by_xpath(".//div").get_attribute('class').split(' ')[1]
        d['Classifiacao MorningStar'] = row.find_element_by_xpath(".//td[starts-with(@id, 'rptFundos_tdMorningstar')]").get_attribute("data-order")
        infos = row.find_elements_by_xpath(".//td")
        d['Nome'] = row.find_element_by_xpath(".//td[starts-with(@id, 'rptFundos_tdNomeFundo')]").text
        print('{0}/{1}: {2}'.format(i+1, total_rows, d['Nome']))
        
        d['Aplicacao minima'] = row.find_element_by_xpath(".//td[starts-with(@id, 'rptFundos_tdAplicacaoMin')]").get_attribute("data-order").split(',')[0]
        d['Taxa adm. a.a. (%)'] = infos[4].text[:-1].replace(',', '.')
        d['Resgate (D+)'] = infos[5].text[-1].replace(',', '.')
        
        if (infos[6].text == 'N/D') or (infos[6].text == 'Não há'): # it's enough to check infos[6]
            d['Rent. mes'] = np.nan
            d['Rent. ano'] = np.nan
            d['Rent. 12M'] = np.nan
            d['Info'] = 0
        else:
            d['Rent. mes'] = infos[6].text[:-1].replace(',', '.')
            d['Rent. ano'] = infos[7].text[:-1].replace(',', '.')
            d['Rent. 12M'] = infos[8].text[:-1].replace(',', '.')
            d['Info'] = 1
        
        status = infos[10].find_element_by_xpath(".//div").get_attribute('class')
        if 'icon-lock' in status:
            d['Status'] = 'Fechado'
        else:  #'btn-group pull-right
            d['Status'] = 'Aberto'
        d['Codigo'] = infos[9].find_element_by_xpath(".//button").get_attribute("data-codigo")
        #d['Pagina'] = 'https://institucional.xpi.com.br/investimentos/fundos-de-investimento/detalhes-de-fundos-de-investimento.aspx?F='+d['Codigo']
        
        # getting the details
        d['Data de inicio'] = row.get_attribute('data-inicio')
        d['Patrimonio'] = row.get_attribute('data-patrimonio')[3:].replace('.', '').replace(',', '.')
        d['Patrimonio 12M'] = row.get_attribute('data-patrimonio12')[3:].replace('.', '').replace(',', '.')
        d['Data da cota'] = row.get_attribute('data-cota')
        d['Valor da cota'] = row.get_attribute('data-valor').replace(',', '.')
        d['Taxa perf. (%)'] = row.get_attribute('data-taxa-performance').replace(',', '.')
        d['Benchmark'] = row.get_attribute('data-benchmark').strip()
        
        funds.append(d)
        
        # estimating remaining time
        diff = time.time() - start_time
        avg_time = diff/(i+1)
        estimated_remaning_time = avg_time*(total_rows-(i+1))
        print('Estimated remaining time (s):', estimated_remaning_time)
    
    driver.quit() 
    
    now = datetime.datetime.now()
    date = now.strftime("%d-%m-%Y")
    file_name = 'xp_funds_surf'
    with open('{0}_{1}.pickle'.format(file_name, date), 'wb') as handle:
        pickle.dump(pd.DataFrame(funds), handle, protocol=pickle.HIGHEST_PROTOCOL)  
    
    return pd.DataFrame(funds)

# %%
df_surf = surf_data()
# Out:
# 1/409: AZ Quest Termo FIRF
# Estimated remaining time (s): 77.19512557983398
# 2/409: Bradesco Asset FIC FIRF CP LP Plus
# Estimated remaining time (s): 77.28116548061371
# 3/409: CA Indosuez DI Master FI Renda Fixa Referenciado DI LP
# Estimated remaining time (s): 73.70647112528482
# 4/409: Mongeral Aegon Renda Fixa Fundo de Investimento
# Estimated remaining time (s): 73.31252932548523
# 5/409: SulAmérica Exclusive FI Referenciado DI
# Estimated remaining time (s): 71.53373622894287
# 6/409: Trend DI Simples FIRF
# Estimated remaining time (s): 72.57956492900848
# 7/409: Trend Pós-Fixado FIRF Simples
# Estimated remaining time (s): 71.50908034188407
# 8/409: Absolute Alpha FIC FIM
# Estimated remaining time (s): 70.70762497186661
# 9/409: AF Invest Geraes FIRF CP
# Estimated remaining time (s): 69.87482706705728
# 10/409: ARX Denali FIC FIRF CP
# Estimated remaining time (s): 69.36644961833954
# 11/409: ARX Vinson FIRF CP
# Estimated remaining time (s): 68.9660096168518
# 12/409: Az Quest Low Vol FIM
# Estimated remaining time (s): 68.7992276350657
# 13/409: AZ Quest Luce Advisory FIC FIRF CP LP
# Estimated remaining time (s): 68.6057785474337
# 14/409: AZ Quest Luce FIC FI RF CP LP
# Estimated remaining time (s): 68.22550577776772
# 15/409: AZ Quest Valore FI Renda Fixa CP
# Estimated remaining time (s): 67.98240588506063
# 16/409: BNP Paribas Match DI FI Referenciado Crédito Privado
# Estimated remaining time (s): 67.89743037521839
# 17/409: BNP Paribas RF FI Renda Fixa
# Estimated remaining time (s): 67.78674664216882
# 18/409: BNP Paribas Rubi FIC FIRF CP
# Estimated remaining time (s): 67.64745570553673
# 19/409: Brasil Plural Crédito Corporativo II FIC FIRF CP LP
# Estimated remaining time (s): 67.51204678886815
# 20/409: Brasil Plural High Yield FI RF Crédito Privado
# Estimated remaining time (s): 67.25131000280379
# 21/409: BTG Pactual Explorer FIM
# Estimated remaining time (s): 67.34876664479575
# 22/409: CA Indosuez Agilité FIRF CP
# Estimated remaining time (s): 67.1215992190621
# 23/409: CA Indosuez Grand Vitesse FIRF CP
# Estimated remaining time (s): 66.99287858216658
# 24/409: CA Indosuez Vitesse FIRF Crédito Privado
# Estimated remaining time (s): 66.82243714729944
# 25/409: Claritas Institucional FIM
# Estimated remaining time (s): 66.65683959960937
# 26/409: Compass FIC FIRF CP LP
# Estimated remaining time (s): 66.54191847030933
# 27/409: Daycoval Classic FIRF Crédito Privado
# Estimated remaining time (s): 66.37958152205856
# 28/409: DLM Hedge Conservador FIM
# Estimated remaining time (s): 66.2730324779238
# 29/409: DLM Hedge Conservador II FIRF CP
# Estimated remaining time (s): 66.21923413769953
# 30/409: DLM Premium 30 FIRF CP LP
# Estimated remaining time (s): 66.11372176011403
# 31/409: DNA Strategy FIC FIM CP
# Estimated remaining time (s): 65.67036022678498
# 32/409: Gama TOP FIC FIRF CP LP
# Estimated remaining time (s): 65.60000364482403
# 33/409: Gauss Income FIC FIRF CP
# Estimated remaining time (s): 65.50558119109184
# 34/409: Icatu Vanguarda Crédito Privado FIRF LP
# Estimated remaining time (s): 65.40649515741012
# 35/409: Iridium Apollo FIRF Crédito Privado Longo Prazo
# Estimated remaining time (s): 65.31060153416225
# 36/409: Iridium Titan Advisory FIC FI RF CP
# Estimated remaining time (s): 65.25486918290457
# 37/409: JGP Corporate FIC FIRF CP LP - Feeder III
# Estimated remaining time (s): 65.1874370832701
# 38/409: Journey Capital Expedition Advisory FICFIRF CP
# Estimated remaining time (s): 65.1419838415949
# 39/409: Journey Capital Voyager Advisory FIC FIRF CP LP
# Estimated remaining time (s): 65.15102300888452
# 40/409: Kinea RF Absoluto FI LP
# Estimated remaining time (s): 65.13756764531135
# 41/409: Mongeral Aegon Crédito Privado FIRF LP
# Estimated remaining time (s): 65.09262717642434
# 42/409: Polo Crédito Corporativo Advisory FIRF CP LP
# Estimated remaining time (s): 65.07093506199973
# 43/409: Porto Seguro Clássico FIC Renda Fixa LP
# Estimated remaining time (s): 65.0186386884645
# 44/409: Porto Seguro FI Referenciado DI Crédito Privado
# Estimated remaining time (s): 64.96362572366542
# 45/409: Quasar Advantage FIRF CP LP
# Estimated remaining time (s): 64.90288912455242
# 46/409: Quasar Advantage Plus FIRF CP LP
# Estimated remaining time (s): 64.82494228300841
# 47/409: Schroder Premium Advisory FIRF CP LP
# Estimated remaining time (s): 64.77640925062464
# 48/409: Selection FIC FI Renda Fixa CP LP
# Estimated remaining time (s): 64.73674797515073
# 49/409: Sparta Max Advisory FIC FIRF CP LP
# Estimated remaining time (s): 64.67800432321977
# 50/409: Sparta Premium FIC FI Referenciado DI Crédito Privado
# Estimated remaining time (s): 64.6536394739151
# 51/409: Sparta Top Advisory FIC FIRF CP LP
# Estimated remaining time (s): 64.59205584432564
# 52/409: Sparta Top FIC FI RF Crédito Privado Longo Prazo
# Estimated remaining time (s): 64.53922373056412
# 53/409: SulAmérica Endurance FIM
# Estimated remaining time (s): 64.48723004898935
# 54/409: SulAmérica Evolution FI Multimercado
# Estimated remaining time (s): 64.43390358377385
# 55/409: SulAmérica Excellence FI Renda Fixa Crédito Privado
# Estimated remaining time (s): 64.36388342597267
# 56/409: SulAmérica Renda Fixa Ativo FI LP
# Estimated remaining time (s): 64.29498760189328
# 57/409: SulAmérica Tático FIM
# Estimated remaining time (s): 64.24397036903783
# 58/409: Valora Absolute FIRF Crédito Privado Longo Prazo
# Estimated remaining time (s): 64.18943960913296
# 59/409: Vinci Multiestrategia FIM
# Estimated remaining time (s): 64.12574214450383
# 60/409: Western Asset Total Credit Advisory FIC FIRF CP
# Estimated remaining time (s): 64.07412306070327
# 61/409: XP Crédito Estruturado 15 FIC FIRF CP LP
# Estimated remaining time (s): 64.01368261556156
# 62/409: XP Investor FI Renda Fixa Crédito Privado LP
# Estimated remaining time (s): 63.95024110040357
# 63/409: XP Referenciado FI Referenciado DI CP
# Estimated remaining time (s): 63.901240250420955
# 64/409: XP Top Crédito Privado Renda Fixa FI LP
# Estimated remaining time (s): 63.844711035490036
# 65/409: Absolute Alpha Global Advisory FIC FIM
# Estimated remaining time (s): 63.789698615440955
# 66/409: Absolute Alpha Global FIC FIM
# Estimated remaining time (s): 63.746973391735196
# 67/409: Absolute Hedge FIC FIM
# Estimated remaining time (s): 63.69702653742549
# 68/409: Adam Macro Advisory FIC FIM
# Estimated remaining time (s): 63.64242854539086
# 69/409: ARX Especial Macro FIC FIM
# Estimated remaining time (s): 63.60014514646668
# 70/409: ARX Everest Advisory FIC FIRF CP
# Estimated remaining time (s): 63.570403422628125
# 71/409: ARX Long Short FIC FIM
# Estimated remaining time (s): 63.52350087904594
# 72/409: ARX Target Institucional FIM
# Estimated remaining time (s): 63.45062658190727
# 73/409: Augme 45 Advisory FIC FIRF CP
# Estimated remaining time (s): 63.391779546868314
# 74/409: AZ Quest Altro Advisory FIC FIM CP
# Estimated remaining time (s): 63.33809680229909
# 75/409: AZ Quest Altro FIC FIM CP
# Estimated remaining time (s): 63.27371041615804
# 76/409: AZ Quest Equity Hedge FIC FIM
# Estimated remaining time (s): 63.2094262305059
# 77/409: AZ Quest Yield FIC FI Renda Fixa Longo Prazo
# Estimated remaining time (s): 63.188816987074816
# 78/409: Bahia AM Advisory FIC de FIM
# Estimated remaining time (s): 63.130782203796585
# 79/409: Capitânia Premium FIC FIRF Crédito Privado
# Estimated remaining time (s): 63.08114770092541
# 80/409: Capitânia TOP Crédito Privado FIC FI Renda Fixa
# Estimated remaining time (s): 63.01503918766975
# 81/409: Claritas Global High Yield FIM IE
# Estimated remaining time (s): 62.950805852442606
# 82/409: Claritas Hedge FIC FIM Longo Prazo
# Estimated remaining time (s): 62.95182918339241
# 83/409: Claritas Long Short Advisory FIC FIM
# Estimated remaining time (s): 62.85976679928332
# 84/409: DNA Vision FIC FIM CP
# Estimated remaining time (s): 62.640415273961565
# 85/409: FIC de FI Votorantim Inflation Renda Fixa
# Estimated remaining time (s): 62.55931192285874
# 86/409: Gripen Advisory FIC FIM
# Estimated remaining time (s): 62.48711753446002
# 87/409: Ibiuna Hedge FIC FIM
# Estimated remaining time (s): 62.42042690035941
# 88/409: Icatu Vanguarda FIC FI Inflação Curta Renda Fixa
# Estimated remaining time (s): 62.34746246988123
# 89/409: Iridium Pioneer FI-Infra Incentivado RF
# Estimated remaining time (s): 62.27517803063553
# 90/409: JGP Crédito Advisory FIM CP
# Estimated remaining time (s): 62.19644696447585
# 91/409: JGP Max Advisory FIC FIM
# Estimated remaining time (s): 62.1238735639132
# 92/409: JGP Strategy Advisory FIC FIM
# Estimated remaining time (s): 62.04154814067094
# 93/409: Kinea Chronos FIM
# Estimated remaining time (s): 61.97033708839007
# 94/409: Mauá Institucional FIC FIM
# Estimated remaining time (s): 61.88833263326198
# 95/409: Navi Long Short FIC FIM
# Estimated remaining time (s): 61.80946299402338
# 96/409: Novus Institucional FIC FIM
# Estimated remaining time (s): 61.721508257091045
# 97/409: Occam Equity Hedge FIC FIM
# Estimated remaining time (s): 61.64768724343211
# 98/409: Occam Institucional FIC FIM II
# Estimated remaining time (s): 61.573278867468545
# 99/409: Opportunity Market FIC DE FIM
# Estimated remaining time (s): 61.48545204991042
# 100/409: PIMCO Income FIC FIM IE
# Estimated remaining time (s): 61.40474662542343
# 101/409: Riza Daikon Advisory FIC FIM CP
# Estimated remaining time (s): 61.19938720098817
# 102/409: Schroder High Grade Advisory FIRF CP
# Estimated remaining time (s): 61.1192362168256
# 103/409: Schroder Liquid Alternatives IE FIM
# Estimated remaining time (s): 61.03402533114536
# 104/409: Selection Debentures Incentivadas Hedge FIC FIM CP
# Estimated remaining time (s): 60.95090564626914
# 105/409: Selection Multimercado FIC FIM
# Estimated remaining time (s): 60.87672377086821
# 106/409: Selection RF Plus FIC FIM CP LP
# Estimated remaining time (s): 60.79350537623999
# 107/409: Sharp Long Short 2X FIM
# Estimated remaining time (s): 60.709700134312996
# 108/409: Sharp Long Short FIM
# Estimated remaining time (s): 60.61287924536952
# 109/409: Solana Long Short FIC de FIM
# Estimated remaining time (s): 60.53329520269271
# 110/409: Solis Capital Antares Advisory CP FIC FIM LP
# Estimated remaining time (s): 60.44910713542591
# 111/409: Solis Capital Antares Crédito Privado FIC FIM LP
# Estimated remaining time (s): 60.371156073905325
# 112/409: Sparta Debentures Incentivadas FIRF CP
# Estimated remaining time (s): 60.28089767907347
# 113/409: SPX Nimitz Feeder FIC de FIM
# Estimated remaining time (s): 60.190774883844156
# 114/409: SPX Seahawk Advisory FIC RF CP LP
# Estimated remaining time (s): 60.10158999970085
# 115/409: SulAmérica Crédito Ativo FI Renda Fixa CP LP
# Estimated remaining time (s): 60.00975056523862
# 116/409: SulAmérica Debêntures Incentivadas Hedge Advisory FIRF CP
# Estimated remaining time (s): 59.91781378614491
# 117/409: SulAmérica Excellence Advisory FI Renda Fixa Crédito Privado
# Estimated remaining time (s): 59.82688288403372
# 118/409: Távola Long Short FIM
# Estimated remaining time (s): 59.742891420752315
# 119/409: Trend Inflação Curta FIRF LP
# Estimated remaining time (s): 59.64788957804191
# 120/409: Trend Pré-Fixado FIRF LP
# Estimated remaining time (s): 59.5525751610597
# 121/409: Verde AM Scena Advisory FIC FIM
# Estimated remaining time (s): 59.46047406157186
# 122/409: Vinci Valorem FI Multimercado
# Estimated remaining time (s): 59.36488465402947
# 123/409: Votorantim FI Eagle Renda Fixa Longo Prazo
# Estimated remaining time (s): 59.26744238535563
# 124/409: Western Asset Multitrading H Multimercado FI
# Estimated remaining time (s): 59.201986116747705
# 125/409: Western Asset Renda Fixa Ativo FI
# Estimated remaining time (s): 59.12082766723633
# 126/409: XP Corporate Plus FIC FIM CP
# Estimated remaining time (s): 59.02147898598323
# 127/409: XP Crédito Estruturado 360 Profissional FIC FIM CP LP IE
# Estimated remaining time (s): 58.92182249910249
# 128/409: XP Debentures Incentivadas Hedge CP FIC FIM LP
# Estimated remaining time (s): 58.82155517861247
# 129/409: XP Inflação Referenciado IPCA FI Renda Fixa LP
# Estimated remaining time (s): 58.73737793560176
# 130/409: XP Macro Institucional FIC FIM
# Estimated remaining time (s): 58.66339570008791
# 131/409: XP Macro Juros Ativo FIC FIRF LP
# Estimated remaining time (s): 58.575627235965875
# 132/409: Aberdeen Multi Asset Growth Advisory FIM IE
# Estimated remaining time (s): 58.49159281904047
# 133/409: Absolute Vertex Advisory FIC FIM
# Estimated remaining time (s): 58.38743709621573
# 134/409: ACE Capital Advisory FIC FIM
# Estimated remaining time (s): 58.284106316851144
# 135/409: Adam Macro Strategy Advisory D60 FIC FIM
# Estimated remaining time (s): 58.179498750192145
# 136/409: Adam Macro Strategy Advisory FIC FIM
# Estimated remaining time (s): 58.076276169103735
# 137/409: Argo Long Short Advisory FIC FIM
# Estimated remaining time (s): 57.971640900103715
# 138/409: ARX Elbrus Advisory Debêntures Incentivadas FIC FIM CP
# Estimated remaining time (s): 57.85875153887099
# 139/409: ARX Extra FIC FIM
# Estimated remaining time (s): 57.752180305316294
# 140/409: ARX Hedge Debêntures Incentivadas FIC FIRF CP
# Estimated remaining time (s): 57.64564424923488
# 141/409: Augme 180 FIC FIM CP
# Estimated remaining time (s): 57.53095194633971
# 142/409: AZ Quest Advisory Total Return FIC FIM
# Estimated remaining time (s): 57.41750107516705
# 143/409: AZ Quest Debentures Incentivadas FIC FIM CP
# Estimated remaining time (s): 57.305813262512636
# 144/409: AZ Quest Multi 15 FIC FIM
# Estimated remaining time (s): 57.19491004943848
# 145/409: AZ Quest Multi FIC FIM
# Estimated remaining time (s): 57.08446418499124
# 146/409: Bahia AM Maraú Advisory FIC de FIM
# Estimated remaining time (s): 56.96831504612753
# 147/409: BlackRock Dynamic High Income FIC FIM IE
# Estimated remaining time (s): 56.85280027843657
# 148/409: Blue Alpha Advisory FIC FIM
# Estimated remaining time (s): 56.73510114727794
# 149/409: BNP Paribas FI-Infra Deb Incentivadas RF
# Estimated remaining time (s): 56.619190401678914
# 150/409: BNP Paribas Inflação FI RF
# Estimated remaining time (s): 56.49930227120718
# 151/409: Canvas Classic II FIC FIM
# Estimated remaining time (s): 56.38356783216363
# 152/409: Canvas Enduro III FIC FIM
# Estimated remaining time (s): 56.26988924804486
# 153/409: Canvas Vector FIC FIM
# Estimated remaining time (s): 56.149766311146855
# 154/409: DLM FI Incentivado Infraestrutura RF CP
# Estimated remaining time (s): 56.027428623917814
# 155/409: DNA Energy FIC FIM CP
# Estimated remaining time (s): 55.83199038044099
# 156/409: Franklin K2 Alternative Strategies FIC FIM IE
# Estimated remaining time (s): 55.71230536546463
# 157/409: Gap Absoluto FIC FIM
# Estimated remaining time (s): 55.5862903109022
# 158/409: GAP Multiportfolio FIM
# Estimated remaining time (s): 55.46477061283739
# 159/409: Garde DArtagnan Advisory FIC FIM
# Estimated remaining time (s): 55.343912832392085
# 160/409: Gávea Macro Advisory FIC FIM
# Estimated remaining time (s): 55.222238758206366
# 161/409: Giant Darius FIC FIM
# Estimated remaining time (s): 55.10247388093367
# 162/409: Giant Sigma Advisory FIC FIM
# Estimated remaining time (s): 54.98294360402189
# 163/409: Ibiuna Hedge STH FIC FIM
# Estimated remaining time (s): 54.85373499642121
# 164/409: Icatu Vanguarda Pré-Fixado FIRF LP
# Estimated remaining time (s): 54.72477229630075
# 165/409: Journey Capital Endurance Debêntures Incentivadas FIRF CP
# Estimated remaining time (s): 54.600266063574594
# 166/409: Journey Capital Endurance Plus Advisory FIC FI-Infra RF LP
# Estimated remaining time (s): 54.47624859896051
# 167/409: JP Morgan Global Bond Opportunities FIC FIM CP - IE Classe A
# Estimated remaining time (s): 54.34094457854768
# 168/409: JP Morgan Global Income Allocation FIC FIM CP IE - Classe A
# Estimated remaining time (s): 54.20872060032118
# 169/409: JP Morgan Global Macro Opportunities FIC FIM IE - Classe A
# Estimated remaining time (s): 54.0826643994574
# 170/409: Kadima II FIC de FIM
# Estimated remaining time (s): 53.948913544767045
# 171/409: Kairós Macro Advisory FIC FIM
# Estimated remaining time (s): 53.81806801913078
# 172/409: Kapitalo Alpha Global Advisory FIQ FIM
# Estimated remaining time (s): 53.690743462983946
# 173/409: Kapitalo Kappa Advisory FIC FIM
# Estimated remaining time (s): 53.56604307648764
# 174/409: Kinea Atlas II FIM
# Estimated remaining time (s): 53.43916649105905
# 175/409: Legacy Capital Advisory FIC FIM
# Estimated remaining time (s): 53.31433107376099
# 176/409: Legg Mason Martin Currie European Absolute Alpha FIM IE
# Estimated remaining time (s): 53.19053908098828
# 177/409: Macro Capital One Advisory FIC FIM
# Estimated remaining time (s): 53.05489637083926
# 178/409: Moat Capital Equity Hedge FIC FIM
# Estimated remaining time (s): 52.92453898606676
# 179/409: Moneda LATAM Credit Advisory FIC FIM IE CP
# Estimated remaining time (s): 52.735026548694634
# 180/409: Morgan Stanley Global Dinâmico Advisory FIC FIM IE
# Estimated remaining time (s): 52.601623284816746
# 181/409: Morgan Stanley Global Fixed Income Advisory FIC FIM IE
# Estimated remaining time (s): 52.46294132780634
# 182/409: MZK Dinâmico Advisory FIC FIM
# Estimated remaining time (s): 52.321716354443474
# 183/409: Neo Multi Estratégia 30 FIC FIM
# Estimated remaining time (s): 52.18726446328919
# 184/409: Neuberger Berman US Multi Cap Opportunities Advisory FIM IE
# Estimated remaining time (s): 51.99472816741985
# 185/409: Novus Macro FIC FIM
# Estimated remaining time (s): 51.85446868071685
# 186/409: Oaktree Global Credit FIC FIM IE
# Estimated remaining time (s): 51.71950234264456
# 187/409: Occam Retorno Absoluto Advisory FIC FIM
# Estimated remaining time (s): 51.57777280603501
# 188/409: Occam Retorno Absoluto FIC FIM
# Estimated remaining time (s): 51.43140524245323
# 189/409: Opportunity Total FIC de FIM
# Estimated remaining time (s): 51.31378246993615
# 190/409: Pacifico Macro FIC FIM
# Estimated remaining time (s): 51.1516796237544
# 191/409: Perfin Equity Hedge FIC FIM
# Estimated remaining time (s): 50.990016924773215
# 192/409: Persevera Compass Advisory FIC FIM
# Estimated remaining time (s): 50.83087797587117
# 193/409: Polo High Yield I FIC FIM CP
# Estimated remaining time (s): 50.67360969899232
# 194/409: Porto Seguro Juro Real FIC RF LP
# Estimated remaining time (s): 50.5120139515277
# 195/409: Porto Seguro Macro FIC FIM
# Estimated remaining time (s): 50.35397325906998
# 196/409: Quasar FI-Infra RF
# Estimated remaining time (s): 50.19655254787328
# 197/409: RPS Equity Hedge Advisory D30 FIC FIM
# Estimated remaining time (s): 50.036032144188276
# 198/409: RPS Equity Hedge D30 FIC FIM
# Estimated remaining time (s): 49.86864123079512
# 199/409: Selection ESG FIC FIA
# Estimated remaining time (s): 49.65549935048549
# 200/409: Selection Mult Internacional FIC FIM IE
# Estimated remaining time (s): 49.44951104998589
# 201/409: Selection Multimercado Acesso FIC FIM
# Estimated remaining time (s): 49.28660517071017
# 202/409: Selection Multimercado Plus FIC FIM
# Estimated remaining time (s): 49.1257116582134
# 203/409: SulAmérica Debêntures Incentivadas FIM CP
# Estimated remaining time (s): 48.96319306190378
# 204/409: SulAmérica Inflatie FI Renda Fixa Longo Prazo
# Estimated remaining time (s): 48.79894288147197
# 205/409: Terape FIC FIM
# Estimated remaining time (s): 48.583622095061514
# 206/409: Tork 60 Advisory FIC FIA
# Estimated remaining time (s): 48.42111267742601
# 207/409: Trend ESG Global Dólar FIM
# Estimated remaining time (s): 48.21233487935458
# 208/409: Trend High Yield Americano FIM
# Estimated remaining time (s): 48.00766388957317
# 209/409: Trend Imobiliário Americano FIM
# Estimated remaining time (s): 47.7886952851948
# 210/409: Trend Inflação Geral FIRF LP
# Estimated remaining time (s): 47.63028012911479
# 211/409: Truxt Long Short Advisory FIC FIM
# Estimated remaining time (s): 47.46627061626923
# 212/409: Truxt Macro Advisory FIC FIM
# Estimated remaining time (s): 47.29927932991171
# 213/409: Vinci Atlas FIC FIM
# Estimated remaining time (s): 47.136764208475746
# 214/409: Vinland Macro Advisory FIC FIM
# Estimated remaining time (s): 46.97416925541708
# 215/409: Vintage Macro Advisory FIC FIM
# Estimated remaining time (s): 46.806753444671635
# 216/409: Vista Long Biased Advisory FIC FIM
# Estimated remaining time (s): 46.5899680323071
# 217/409: VRB Fundo de Investimento Multimercado
# Estimated remaining time (s): 46.421234482444376
# 218/409: Western Asset Macro Strategies FIC de FIM IE
# Estimated remaining time (s): 46.2517983574386
# 219/409: XP Debentures Incentivadas Crédito Privado FIC FIM
# Estimated remaining time (s): 46.0851308199913
# 220/409: XP Long Short 60 FIC FIM
# Estimated remaining time (s): 45.91896133531224
# 221/409: XP Long Short FIC FIM
# Estimated remaining time (s): 45.74796041859761
# 222/409: XP Macro FIM
# Estimated remaining time (s): 45.57867491674853
# 223/409: Absolute Pace Long Biased Advisory FIC FIA
# Estimated remaining time (s): 45.4046336995112
# 224/409: Alaska Black FIC FIA - BDR Nível I
# Estimated remaining time (s): 45.23137969630105
# 225/409: Alaska Black Institucional FIA
# Estimated remaining time (s): 45.062058156331375
# 226/409: Alpha Key Long Biased II FIC FIM
# Estimated remaining time (s): 44.88618014555062
# 227/409: Apex Ações 30 FIC FIA
# Estimated remaining time (s): 44.71120832460042
# 228/409: Apex Long Biased Advisory FIC FIM
# Estimated remaining time (s): 44.539157023555354
# 229/409: ARX Income FIC FIA
# Estimated remaining time (s): 44.36184021062726
# 230/409: ARX Long Term FIC FIA
# Estimated remaining time (s): 44.18704459148905
# 231/409: Athena Total Return II FIC FIA
# Estimated remaining time (s): 44.01125500418923
# 232/409: Atlas One FIC FIA
# Estimated remaining time (s): 43.832477053691605
# 233/409: AXA WF Framlington Digital Economy Advisory FIC FIA IE
# Estimated remaining time (s): 43.65199602315354
# 234/409: AXA WF Framlington Robotech Advisory FIC FIA IE
# Estimated remaining time (s): 43.47374446881123
# 235/409: AXA WF US High Yield Bonds Advisory FIC FIM IE CP
# Estimated remaining time (s): 43.29317869024074
# 236/409: AZ Quest Ações FIC FIA
# Estimated remaining time (s): 43.11264140121007
# 237/409: AZ Quest Multi Max FIC FIM
# Estimated remaining time (s): 42.93696154018998
# 238/409: AZ Quest Small Mid Caps FIC FIA
# Estimated remaining time (s): 42.75113503872847
# 239/409: AZ Quest TOP Long Biased FIC FIA
# Estimated remaining time (s): 42.56774028474816
# 240/409: Bahia AM Long Biased FIC FIM
# Estimated remaining time (s): 42.393739816546436
# 241/409: Bahia AM Long Biased II Advisory FIC FIM
# Estimated remaining time (s): 42.156544918835905
# 242/409: Bahia AM Valuation FIC FIA
# Estimated remaining time (s): 41.953343434767284
# 243/409: BNP Paribas Action FIC FIA
# Estimated remaining time (s): 41.75125708795869
# 244/409: BNP Paribas Small Caps FIA
# Estimated remaining time (s): 41.54499317290353
# 245/409: Bozano Growth Advisory FIC FIM
# Estimated remaining time (s): 41.340799802663376
# 246/409: Bradesco Asset FIC FIA Crescimento
# Estimated remaining time (s): 41.13639750034828
# 247/409: Brasil Capital 30 Advisory FIC FIA
# Estimated remaining time (s): 40.930362438866
# 248/409: Brasil Capital 30 FIC FIA
# Estimated remaining time (s): 40.723000887901556
# 249/409: CA Indosuez Debêntures Incentivadas CP FIC FIM
# Estimated remaining time (s): 40.51728658408046
# 250/409: Canvas Dakar Long Bias FIC FIM
# Estimated remaining time (s): 40.312040410995486
# 251/409: Capitânia Reit 90 CP FIC FIM
# Estimated remaining time (s): 40.10508458072921
# 252/409: Claritas Long Bias Advisory FIC FIM
# Estimated remaining time (s): 39.86582928044455
# 253/409: Claritas Total Return FIC FIM
# Estimated remaining time (s): 39.65994950622438
# 254/409: Claritas Valor Feeder FIA
# Estimated remaining time (s): 39.45149862390804
# 255/409: Constellation Institucional Advisory FIC FIA
# Estimated remaining time (s): 39.24309250700708
# 256/409: Constellation Institucional FIC FIA
# Estimated remaining time (s): 39.03934537153691
# 257/409: Dahlia Institucional Advisory FIC FIA
# Estimated remaining time (s): 38.835215460929426
# 258/409: Dahlia Total Return Advisory FIC FIM
# Estimated remaining time (s): 38.6309494972229
# 259/409: Dahlia Total Return FIC FIM
# Estimated remaining time (s): 38.42506841342882
# 260/409: Empirica Lotus FIC FIM CP
# Estimated remaining time (s): 38.21827103724846
# 261/409: Equitas Selection Advisory FIC FIA
# Estimated remaining time (s): 37.97681215805112
# 262/409: Equitas Selection FIC FIA
# Estimated remaining time (s): 37.77215549327035
# 263/409: Exodus 180 FIC FIM Credito Privado
# Estimated remaining time (s): 37.56214646604125
# 264/409: Exodus 360 FIC FIM Credito Privado
# Estimated remaining time (s): 37.35299278840874
# 265/409: Exodus 60 FIC FIM Crédito Privado
# Estimated remaining time (s): 37.278021542531135
# 266/409: Exodus 90 FIC FIM Credito Privado
# Estimated remaining time (s): 37.05022267739576
# 267/409: Exploritas Alpha America Latina FIC FIM
# Estimated remaining time (s): 36.83629468853554
# 268/409: FAMA FIC FIA
# Estimated remaining time (s): 36.59990559851945
# 269/409: Franklin Valor e Liquidez FVL FIC FIA
# Estimated remaining time (s): 36.363164323856395
# 270/409: Gama Bridgewater Global Risk Premium USD FIC FIM IE
# Estimated remaining time (s): 36.10256241957347
# 271/409: Garde Athos Long Biased FIC FIM
# Estimated remaining time (s): 35.865604222920545
# 272/409: Gauss Advisory FIC FIM
# Estimated remaining time (s): 35.62813306731336
# 273/409: Geo Empresas Globais em Reais FIC FIA IE
# Estimated remaining time (s): 35.395702704405174
# 274/409: Geo Empresas Globais FIC FIA IE
# Estimated remaining time (s): 35.15606690497294
# 275/409: Giant Zarathustra FIC FIM
# Estimated remaining time (s): 34.914421738711276
# 276/409: Hashdex Criptoativos Discovery FIC FIM
# Estimated remaining time (s): 34.6740497307501
# 277/409: HIX Capital Advisory FIC FIA
# Estimated remaining time (s): 34.43432084920174
# 278/409: HIX Capital FIA
# Estimated remaining time (s): 34.19222632329241
# 279/409: Ibiuna Equities 30 FIC FIA
# Estimated remaining time (s): 33.9510946461804
# 280/409: Ibiuna Long Biased FIC FIM
# Estimated remaining time (s): 33.71167797446251
# 281/409: Ibiuna Long Short Advisory FIC FIM
# Estimated remaining time (s): 33.46968844267821
# 282/409: Ibiuna Long Short STLS FIC FIM
# Estimated remaining time (s): 33.23449850251489
# 283/409: Icatu Vanguarda Dividendos 30 FIA
# Estimated remaining time (s): 32.99280594262975
# 284/409: Icatu Vanguarda Dividendos FIA
# Estimated remaining time (s): 32.75007166912858
# 285/409: Icatu Vanguarda FIC FI Inflação Longa Renda Fixa
# Estimated remaining time (s): 32.50746801945201
# 286/409: Indie FIC FIA
# Estimated remaining time (s): 32.26609405687639
# 287/409: IP - Participações IPG FIC FIA BDR Nível I
# Estimated remaining time (s): 32.02317839964757
# 288/409: IP Atlas USD FIC FIA IE
# Estimated remaining time (s): 31.761507987148235
# 289/409: IP Value Hedge FIC FIA BDR Nivel I
# Estimated remaining time (s): 31.520414022425882
# 290/409: JGP Equity FIC FIM
# Estimated remaining time (s): 31.288240635806112
# 291/409: JGP Long Only FIC FIA
# Estimated remaining time (s): 31.046055107182244
# 292/409: Journey Capital Endurance Deb Incentivadas Juros Reais Advisory FICFI-Infra
# Estimated remaining time (s): 30.80230857493126
# 293/409: JP Morgan Dólar Global Macro Opportunities FIM - IE
# Estimated remaining time (s): 30.56126728643736
# 294/409: Kapitalo Tarkus FIC FIA
# Estimated remaining time (s): 30.318603531843948
# 295/409: Kiron FIC FIA
# Estimated remaining time (s): 30.073574381359556
# 296/409: Leblon Ações FIC FIA
# Estimated remaining time (s): 29.82934129640863
# 297/409: Legg Mason Clearbridge US Large Cap Growth FIA IE
# Estimated remaining time (s): 29.584302690294052
# 298/409: Mauá Capital Ações FIC FIA
# Estimated remaining time (s): 29.339363422969846
# 299/409: Mauá Macro Advisory FIC FIM
# Estimated remaining time (s): 29.093982184611036
# 300/409: Miles Acer Long Bias Advisory FIC FIM
# Estimated remaining time (s): 28.84872517347336
# 301/409: Miles Virtus Advisory FIC FIA
# Estimated remaining time (s): 28.60285739645213
# 302/409: Moat Capital Advisory FIC FIA
# Estimated remaining time (s): 28.339966364254224
# 303/409: Moat Capital FIC FIA
# Estimated remaining time (s): 28.09531573179138
# 304/409: Moat Capital Long Bias Advisory FIC FIM
# Estimated remaining time (s): 27.848588632125605
# 305/409: Morgan Stanley Global Opportunity Dolar Advisory FIC FIA IE
# Estimated remaining time (s): 27.602636624945973
# 306/409: Navi Cruise Advisory FIC FIA
# Estimated remaining time (s): 27.35617109918906
# 307/409: Navi Institucional FIC FIA
# Estimated remaining time (s): 27.113654257808523
# 308/409: NCH Maracanã FIA
# Estimated remaining time (s): 26.864168326576035
# 309/409: Neo Navitas B FIC FIA
# Estimated remaining time (s): 26.61766542971713
# 310/409: Novus Ações Institucional FIC FIA
# Estimated remaining time (s): 26.368222182027754
# 311/409: Novus Retorno Absoluto FIC FIM
# Estimated remaining time (s): 26.119080089679485
# 312/409: Occam FIC FIA
# Estimated remaining time (s): 25.87164505322774
# 313/409: Occam Long & Short Plus FIC FIM
# Estimated remaining time (s): 25.622850095121244
# 314/409: Occam Long Biased Advisory FIC FIM
# Estimated remaining time (s): 25.35768695697663
# 315/409: Oceana Long Biased Advisory FIC FIM
# Estimated remaining time (s): 25.109566679454986
# 316/409: Opportunity Long Biased FIC FIM
# Estimated remaining time (s): 24.861840080611316
# 317/409: Opportunity Selection FIC FIA
# Estimated remaining time (s): 24.613635493377785
# 318/409: Pacifico Ações FIC FIA
# Estimated remaining time (s): 24.365402628040915
# 319/409: Pacifico LB FIC FIM
# Estimated remaining time (s): 24.115652798858928
# 320/409: Paineiras Hedge II FIC FIM
# Estimated remaining time (s): 23.86455111950636
# 321/409: Perfin Foresight Institucional FIC FIA
# Estimated remaining time (s): 23.615444878551447
# 322/409: PIMCO Income Dólar FIC FIM IE
# Estimated remaining time (s): 23.367036587703303
# 323/409: Polo Long Bias FIM
# Estimated remaining time (s): 23.11527365132382
# 324/409: Polo Norte I FIC FIM
# Estimated remaining time (s): 22.86478712234968
# 325/409: Porto Seguro FIC Ações
# Estimated remaining time (s): 22.61235694004939
# 326/409: Porto Seguro Selecta FIC FIA
# Estimated remaining time (s): 22.360501856160308
# 327/409: Reach FIA
# Estimated remaining time (s): 22.107954798123888
# 328/409: Reach Total Return FIC FIA
# Estimated remaining time (s): 21.854475569434282
# 329/409: Redpoint eventures Advisory FIC FIM CP
# Estimated remaining time (s): 21.601132158088102
# 330/409: Riza Meyenii 180 Advisory FIC FIM CP
# Estimated remaining time (s): 21.335626525589916
# 331/409: RPS Long Bias Advisory D60 FIC FIA
# Estimated remaining time (s): 21.08280744293305
# 332/409: RPS Selection FIC FIA
# Estimated remaining time (s): 20.828360265996082
# 333/409: Safari 45 FIC FIM II
# Estimated remaining time (s): 20.57436048948729
# 334/409: Safari FIC FIM II
# Estimated remaining time (s): 20.32067509825358
# 335/409: Selection Ações FIC FIA
# Estimated remaining time (s): 20.065656969440518
# 336/409: Selection Long Biased FIC FIM
# Estimated remaining time (s): 19.811426456485474
# 337/409: Sharp Equity Value Institucional FIA
# Estimated remaining time (s): 19.556060768376472
# 338/409: Sharp Ibovespa Ativo FIA
# Estimated remaining time (s): 19.29929782300306
# 339/409: Sharp Long Biased Advisory FIC FIA
# Estimated remaining time (s): 19.043145700190273
# 340/409: Solana Absolutto FIC FIM
# Estimated remaining time (s): 18.789534111583936
# 341/409: SPX Falcon FIC FIA
# Estimated remaining time (s): 18.530824912957783
# 342/409: SPX Patriot FIC FIA
# Estimated remaining time (s): 18.273301913724307
# 343/409: Starboard Special Situations II Advisory FIC FIM CP
# Estimated remaining time (s): 18.013882162967157
# 344/409: Studio 30 FIC FIA
# Estimated remaining time (s): 17.754771608945937
# 345/409: SulAmérica Equities FIA
# Estimated remaining time (s): 17.495672607421874
# 346/409: Tarpon GT FIC FIA
# Estimated remaining time (s): 17.235545332721202
# 347/409: Távola Absoluto Advisory FIC FIM
# Estimated remaining time (s): 16.974983587732233
# 348/409: Távola Absoluto FIM
# Estimated remaining time (s): 16.715081570477324
# 349/409: Templeton Global Total Return FIC FIM IE
# Estimated remaining time (s): 16.45420525340433
# 350/409: Tork FIC FIA
# Estimated remaining time (s): 16.193073784283232
# 351/409: Tork Long Only Institucional FIC FIA
# Estimated remaining time (s): 15.93168184220621
# 352/409: Trend Bolsa Americana Alavancado FIA
# Estimated remaining time (s): 15.660869087007912
# 353/409: Trend Bolsa Americana Dolar FIM
# Estimated remaining time (s): 15.398922625749714
# 354/409: Trend Bolsa Americana FIM
# Estimated remaining time (s): 15.136384569992455
# 355/409: Trend Bolsa Chinesa FIM
# Estimated remaining time (s): 14.864923333450102
# 356/409: Trend Bolsas Globais FIM
# Estimated remaining time (s): 14.593683536133069
# 357/409: Trend Dólar FI Cambial
# Estimated remaining time (s): 14.33055795140627
# 358/409: Trend ESG Global FIM
# Estimated remaining time (s): 14.058838519970132
# 359/409: Trend Estatais FIA
# Estimated remaining time (s): 13.79455633482229
# 360/409: Trend Ibovespa Alavancado FIA
# Estimated remaining time (s): 13.530632179313235
# 361/409: Trend Ibovespa Balanceado FIM
# Estimated remaining time (s): 13.26597377534058
# 362/409: Trend Ibovespa Dolar FIA
# Estimated remaining time (s): 13.000973312894283
# 363/409: Trend Ibovespa FIA
# Estimated remaining time (s): 12.736054977438009
# 364/409: Trend Imobiliario FIC FIM
# Estimated remaining time (s): 12.463118512551862
# 365/409: Trend Ouro Dólar FIM
# Estimated remaining time (s): 12.19745525987181
# 366/409: Trend Ouro FIM
# Estimated remaining time (s): 11.930745010167524
# 367/409: Trend Short Dolar FI Cambial
# Estimated remaining time (s): 11.663248567555192
# 368/409: Trend Small Caps FIA
# Estimated remaining time (s): 11.390924578127652
# 369/409: Trend Tecnologia FIM
# Estimated remaining time (s): 11.122838100443689
# 370/409: Trend XP Inc Balanceado FIC FIM
# Estimated remaining time (s): 10.85434366561271
# 371/409: Trend XP Inc FIC FIA IE
# Estimated remaining time (s): 10.5862074181076
# 372/409: Truxt I Valor Institucional FIC FIA
# Estimated remaining time (s): 10.316604289957272
# 373/409: Truxt Long Bias Advisory FIC FIM
# Estimated remaining time (s): 10.047290781547813
# 374/409: Valora Guardian Advisory FIC FIM CP
# Estimated remaining time (s): 9.777316186517318
# 375/409: Velt 120 Advisory FIC FIA
# Estimated remaining time (s): 9.501168294270833
# 376/409: Verde AM Long Bias FIC FIA
# Estimated remaining time (s): 9.230722736805044
# 377/409: Vinci Crédito Estruturado Selection Advisory FIC FIM Crédito Privado
# Estimated remaining time (s): 8.959797846543694
# 378/409: Vinci Mosaico FIA
# Estimated remaining time (s): 8.687559123392457
# 379/409: Vinci Seleção FIA
# Estimated remaining time (s): 8.415068447747142
# 380/409: Vinland Long Bias Advisory FIC FIM
# Estimated remaining time (s): 8.14207130294097
# 381/409: Vinland Long Only FIC FIA
# Estimated remaining time (s): 7.868724840519622
# 382/409: Vista FIC FIA
# Estimated remaining time (s): 7.595335109695715
# 383/409: Vista Hedge FIM
# Estimated remaining time (s): 7.3215477958360475
# 384/409: Vista Multiestratégia FIM
# Estimated remaining time (s): 7.046723707268636
# 385/409: Votorantim FIC de FI Cambial Dólar
# Estimated remaining time (s): 6.77178397735992
# 386/409: Wellington Ventura Advisory FIA IE
# Estimated remaining time (s): 6.492719986278159
# 387/409: Wellington Ventura Dolar Advisory FIC FIA IE
# Estimated remaining time (s): 6.213374411412912
# 388/409: Western Asset FIA BDR Nivel I
# Estimated remaining time (s): 5.937823451056923
# 389/409: Western Asset Hedge Dólar FI Cambial
# Estimated remaining time (s): 5.660677176821202
# 390/409: Western Asset US Index 500 FIM
# Estimated remaining time (s): 5.382807289637052
# 391/409: XP Ações FIC FIA
# Estimated remaining time (s): 5.104356421838941
# 392/409: XP Crédito Estruturado 180 FIC FIM CP
# Estimated remaining time (s): 4.825387604382573
# 393/409: XP Crédito Estruturado 360 FIC FIM CP
# Estimated remaining time (s): 4.5457757071381
# 394/409: XP Dividendos 30 FIC FIA
# Estimated remaining time (s): 4.2656673907023395
# 395/409: XP Dividendos FIA
# Estimated remaining time (s): 3.984936780567411
# 396/409: XP Investor 30 FIC FIA
# Estimated remaining time (s): 3.703631037413472
# 397/409: XP Investor FIA
# Estimated remaining time (s): 3.422106915817453
# 398/409: XP Long Biased 30 FIC FIM
# Estimated remaining time (s): 3.139816098476774
# 399/409: XP Long Biased Advisory FIC FIM
# Estimated remaining time (s): 2.856975874506441
# 400/409: XP Long Biased III FIC FIM
# Estimated remaining time (s): 2.5723459643125532
# 401/409: XP Long Term Equity FIC FIM
# Estimated remaining time (s): 2.2886289705956666
# 402/409: XP Macro Plus FIC FIM
# Estimated remaining time (s): 2.0044907722900165
# 403/409: XPA Portfolio Private II FIC FIM CP
# Estimated remaining time (s): 1.7197569724052184
# 404/409: Absolute Alpha Marb Advisory FIC FIM
# Estimated remaining time (s): 1.4345401023874187
# 405/409: AF Invest Geraes 30 FIRF CP
# Estimated remaining time (s): 1.1487998514999578
# 406/409: FMB FIC FIM CP
# Estimated remaining time (s): 0.8624475125608773
# 407/409: Genoa Capital Radar Advisory FIC FIM
# Estimated remaining time (s): 0.5752045364286156
# 408/409: Trend Tesouro Americano FIM
# Estimated remaining time (s): 0.28778357540859895
# 409/409: XP Fundo de Fundos Imobiliarios 90 FIC FIM CP
# Estimated remaining time (s): 0.0

# %%
df_surf[100:105]
# Out:
#           Risco Classifiacao MorningStar  \
# 100  RiscoMedio                        0
# 101  RiscoMedio                        0
# 102  RiscoMedio                        0
# 103  RiscoMedio                        0
# 104  RiscoMedio                        2
#
#                                                   Nome Aplicacao minima  \
# 100                    Riza Daikon Advisory FIC FIM CP             5000
# 101               Schroder High Grade Advisory FIRF CP             1000
# 102                Schroder Liquid Alternatives IE FIM             5000
# 103  Selection Debentures Incentivadas Hedge FIC FI...              100
# 104                     Selection Multimercado FIC FIM              100
#
#     Taxa adm. a.a. (%) Resgate (D+) Rent. mes Rent. ano Rent. 12M  Info  \
# 100               0.80            0       NaN       NaN       NaN     0
# 101               0.60            0      0.34     -5.37     -3.95     1
# 102               1.00            7      0.67     -0.55      2.72     1
# 103               0.50            0      0.26      0.52     -0.32     1
# 104               0.75            0      0.17     -1.49      1.20     1
#
#      Status  Codigo Data de inicio    Patrimonio Patrimonio 12M Data da cota  \
# 100  Aberto  800952     30/03/2020   14508766.52     7576182.05   14/08/2020
# 101  Aberto  800610     26/12/2018  137446650.72   267747826.58   14/08/2020
# 102  Aberto    2862     22/09/2016   15097149.06    19001228.52   14/08/2020
# 103  Aberto  800702     26/04/2019  101480316.39   193733082.09   13/08/2020
# 104  Aberto    2813     25/08/2016  125695269.59    99724927.81   13/08/2020
#
#     Valor da cota Taxa perf. (%) Benchmark
# 100    1.07666170          20.00       CDI
# 101    1.00998387              -       CDI
# 102    1.22930188              -       CDI
# 103    1.01090745          20.00       CDI
# 104    1.32009703          20.00       CDI

# %%
getsizeof(df_surf)/1000000 # size in MBs
# Out:
# 0.483767

# %% [markdown]
# #### 2. Getting detailed information

# %% [markdown]
# First, we'll walk through the page, testing whether the XPath commands are working in particular fund. Then, we'll build a function combining all commmands that will be used for scraping.

# %%
fund_code = 2862
fund_page = 'https://institucional.xpi.com.br/investimentos/fundos-de-investimento/detalhes-de-fundos-de-investimento.aspx?F='+str(fund_code)
options = webdriver.ChromeOptions()
#options.add_argument("--headless")
driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver.exe')
driver.get(fund_page)

# %% [markdown]
# All information below are not necessary as them are available at the main page.

# %%
infos = driver.find_elements_by_xpath("//table[@class='table table-bordered table-hover tabelaXP']/tbody/tr/td")
d = {}
d['Data'] = infos[0].text
d['Cota'] = infos[1].text.replace(',', '.')
d['Rent. dia'] = infos[2].text[:-1].replace(',', '.')
d['PL atual (R$)'] = infos[6].text[2:].replace('.', '').replace(',', '.')
d['PL medio anual (R$)'] = infos[7].text[2:].replace('.', '').replace(',', '.')
print(d)
# Out:
# {'Data': '14/08/2020', 'Cota': '1.22930188', 'Rent. dia': '-0.04', 'PL atual (R$)': ' 15097149.06', 'PL medio anual (R$)': ' 19001228.52'}

# %%
d = {}
driver.find_element_by_xpath("//a[text()='Características do Fundo']").click()
time.sleep(1) # add a wait here
# d['Inicio'] = driver.find_element_by_xpath("//div[@class='tab-pane fade active in']/table/tbody/tr[1]/td[2]/h4").text
d['Objetivos'] = driver.find_element_by_xpath("//strong[text()='Objetivos']/ancestor::p/following-sibling::p").text.strip()
d['Publico-alvo'] = driver.find_element_by_xpath("//strong[text()='Público-alvo']/ancestor::p/following-sibling::p").text.strip()
d['Politica de gestao'] = driver.find_element_by_xpath("//strong[text()='Política de gestão']/ancestor::p/following-sibling::p").text.strip()

# parsing file links
files = driver.find_elements_by_xpath("//div[@id='dvArqsDownload']/div")
links = {}
for file in files:
    link = file.find_element_by_xpath(".//p/a").get_attribute('href')
    name = file.find_element_by_xpath(".//p/a").get_attribute('id')
    links[name] = link
d['Links'] = links
print(d)
# Out:
# {'Objetivos': 'O objetivo do FUNDO é gerar retornos acima do CDI e baixa correlação com as principais classes de ativos domésticas. O produto oferece acesso à plataforma global de alternativos líquidos da Schroders, sendo seu retorno total é rentabilidade dos fundos investidos, combinada ao diferencial de taxa de juros (entre BRL e USD), menos o custo do hedge.', 'Publico-alvo': 'Investidores qualificados', 'Politica de gestao': 'O FUNDO buscará o crescimento de capital investindo, no mínimo, 67% (sessenta e sete por cento) de seu patrimônio líquido em fundos domiciliado no exterior', 'Links': {'lnkProspecto': 'https://institucional.xpi.com.br/downloads/xpgestao/Prospecto/Prospecto_2862_v1.pdf', 'lnkRegulamento': 'https://institucional.xpi.com.br/downloads/xpgestao/Regulamento/Regulamento_24018821000113_v3.pdf', 'lnkLamina': 'https://institucional.xpi.com.br/downloads/xpgestao/Lamina/Lamina_24018821000113_v4.pdf', 'lnkCaracteristica': 'https://institucional.xpi.com.br/downloads/xpgestao/Caracteristica/Caracteristica_24018821000113_v79.pdf'}}

# %%
driver.find_element_by_xpath("//a[text()='Informações complementares']").click()
time.sleep(1) # add a wait here
d['Aplicação Inicial Mínima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Aplicação Inicial Mínima')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
d['Movimentação Mínima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Movimentação Mínima')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
d['Saldo de Permanência'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Saldo de Permanência')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
#d['Taxa de Administração'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa de Administração')]/following-sibling::td").text[:-1].replace(',', '.')
d['Taxa Máxima de Administração'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa Máxima de Administração')]/following-sibling::td").text[:-4].replace(',', '.')
d['Taxa de Performance'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa de Performance')]/following-sibling::td").text.strip()
d['Tributação'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Tributação')]/following-sibling::td").text.strip()
d['IOF'] = driver.find_element_by_xpath("//td[starts-with(text(), 'IOF')]/following-sibling::td").text.strip()
d['Aplicação'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Aplicação\n')]/following-sibling::td").text.strip()
d['Resgate - Cotização'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Resgate - Cotização')]/following-sibling::td").text.strip()
d['Resgate - Liquidação Financeira'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Resgate - Liquidação Financeira')]/following-sibling::td").text.strip()
d['Horário para Aplicação e Resgate'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Horário para Aplicação e Resgate')]/following-sibling::td").text.strip()
d['Divulgação de quota e PL'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Divulgação de quota e PL')]/following-sibling::td").text.strip()
d['Classificação Anbima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Classificação Anbima')]/following-sibling::td").text.strip()
d['Código Anbima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Código Anbima')]/following-sibling::td").text.strip()
d['Custódia'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Custódia')]/following-sibling::td").text.strip()
d['Auditoria'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Auditoria')]/following-sibling::td").text.strip()
d['Gestor'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Gestor')]/following-sibling::td").text.strip()
d['Administrador'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Administrador\n')]/following-sibling::td").text.strip()

# %%
pprint.pprint(d)
# Out:
# {'Administrador': 'BNY Mellon Serviços Financeiros DTVM S.A.',
#  'Aplicação': 'D+0 (Dias Úteis)',
#  'Aplicação Inicial Mínima': '5000.00',
#  'Auditoria': 'KPMG Auditores Independentes',
#  'Classificação Anbima': '',
#  'Custódia': 'BNY Mellon Banco S.A',
#  'Código Anbima': '423998',
#  'Divulgação de quota e PL': '',
#  'Gestor': 'Schroder Investment Management',
#  'Horário para Aplicação e Resgate': '14:30:00',
#  'IOF': 'Começa com uma alíquota de 96% do rendimento e vai a ZERO para quem '
#         'resgatar a partir do 30º dia da data da aplicação.',
#  'Links': {'lnkCaracteristica': 'https://institucional.xpi.com.br/downloads/xpgestao/Caracteristica/Caracteristica_24018821000113_v79.pdf',
#            'lnkLamina': 'https://institucional.xpi.com.br/downloads/xpgestao/Lamina/Lamina_24018821000113_v4.pdf',
#            'lnkProspecto': 'https://institucional.xpi.com.br/downloads/xpgestao/Prospecto/Prospecto_2862_v1.pdf',
#            'lnkRegulamento': 'https://institucional.xpi.com.br/downloads/xpgestao/Regulamento/Regulamento_24018821000113_v3.pdf'},
#  'Movimentação Mínima': '500.00',
#  'Objetivos': 'O objetivo do FUNDO é gerar retornos acima do CDI e baixa '
#               'correlação com as principais classes de ativos domésticas. O '
#               'produto oferece acesso à plataforma global de alternativos '
#               'líquidos da Schroders, sendo seu retorno total é rentabilidade '
#               'dos fundos investidos, combinada ao diferencial de taxa de '
#               'juros (entre BRL e USD), menos o custo do hedge.',
#  'Politica de gestao': 'O FUNDO buscará o crescimento de capital investindo, '
#                        'no mínimo, 67% (sessenta e sete por cento) de seu '
#                        'patrimônio líquido em fundos domiciliado no exterior',
#  'Publico-alvo': 'Investidores qualificados',
#  'Resgate - Cotização': 'D+7 (Dias Corridos)',
#  'Resgate - Liquidação Financeira': 'D+3 (Dias Úteis)',
#  'Saldo de Permanência': '500.00',
#  'Taxa Máxima de Administração': '',
#  'Taxa de Administração': '1',
#  'Taxa de Performance': 'Não há',
#  'Tributação': 'Longo Prazo - Alíquota regressiva de IR de 22,5% a 15,0% '
#                'incidida sobre o lucro obtido no momento do resgate.'}

# %% [markdown]
# Getting the historical performance data. This page was found by looking at the 'Network' tab inside the inspection tool of Chrome browser; specifically, inside the headers of a request url that was loaded inside the inner XHR tab.

# %%
hist_data = "https://institucional.xpi.com.br/api/Ranking/GraficoFundo?idFundo={0}&tipo=3".format(fund_code)
driver.get(hist_data) # 'tipo=3' holds the most lengthy data (at most 36 months)
soup = BeautifulSoup(driver.page_source)
dict_from_json = json.loads(soup.find("body").text)
graph = dict_from_json['Fundo']

# pasing data
for day in graph:
    del day['key']
    day['Date'] = day['Ano'].split('T')[0]
    del day['Ano']
print(graph[0])

# %%
d['Daily profitability'] = pd.DataFrame(graph).set_index('Date')

# %%
pprint.pprint(d)
# Out:
# {'Administrador': 'BNY Mellon Serviços Financeiros DTVM S.A.',
#  'Aplicação': 'D+0 (Dias Úteis)',
#  'Aplicação Inicial Mínima': '5000.00',
#  'Auditoria': 'KPMG Auditores Independentes',
#  'Classificação Anbima': '',
#  'Custódia': 'BNY Mellon Banco S.A',
#  'Código Anbima': '423998',
#  'Daily profitability':                 Valor
# Date
# 2017-08-18   0.000000
# 2017-08-21  -0.040417
# 2017-08-22   0.074214
# 2017-08-23   0.417737
# 2017-08-24   0.169065
# ...               ...
# 2020-08-07  10.398753
# 2020-08-10  10.216926
# 2020-08-11  10.157575
# 2020-08-12  10.472335
# 2020-08-13  10.467243
#
# [744 rows x 1 columns],
#  'Divulgação de quota e PL': '',
#  'Gestor': 'Schroder Investment Management',
#  'Horário para Aplicação e Resgate': '14:30:00',
#  'IOF': 'Começa com uma alíquota de 96% do rendimento e vai a ZERO para quem '
#         'resgatar a partir do 30º dia da data da aplicação.',
#  'Links': {'lnkCaracteristica': 'https://institucional.xpi.com.br/downloads/xpgestao/Caracteristica/Caracteristica_24018821000113_v79.pdf',
#            'lnkLamina': 'https://institucional.xpi.com.br/downloads/xpgestao/Lamina/Lamina_24018821000113_v4.pdf',
#            'lnkProspecto': 'https://institucional.xpi.com.br/downloads/xpgestao/Prospecto/Prospecto_2862_v1.pdf',
#            'lnkRegulamento': 'https://institucional.xpi.com.br/downloads/xpgestao/Regulamento/Regulamento_24018821000113_v3.pdf'},
#  'Movimentação Mínima': '500.00',
#  'Objetivos': 'O objetivo do FUNDO é gerar retornos acima do CDI e baixa '
#               'correlação com as principais classes de ativos domésticas. O '
#               'produto oferece acesso à plataforma global de alternativos '
#               'líquidos da Schroders, sendo seu retorno total é rentabilidade '
#               'dos fundos investidos, combinada ao diferencial de taxa de '
#               'juros (entre BRL e USD), menos o custo do hedge.',
#  'Politica de gestao': 'O FUNDO buscará o crescimento de capital investindo, '
#                        'no mínimo, 67% (sessenta e sete por cento) de seu '
#                        'patrimônio líquido em fundos domiciliado no exterior',
#  'Publico-alvo': 'Investidores qualificados',
#  'Resgate - Cotização': 'D+7 (Dias Corridos)',
#  'Resgate - Liquidação Financeira': 'D+3 (Dias Úteis)',
#  'Saldo de Permanência': '500.00',
#  'Taxa Máxima de Administração': '',
#  'Taxa de Administração': '1',
#  'Taxa de Performance': 'Não há',
#  'Tributação': 'Longo Prazo - Alíquota regressiva de IR de 22,5% a 15,0% '
#                'incidida sobre o lucro obtido no momento do resgate.'}

# %% [markdown]
# #### Putting all together into a single function

# %%
def deep_data(codes, infos01, saving=True):
    """
    It scraps detailed data from funds available at the link below and saves them as a pickle file.
    https://institucional.xpi.com.br/investimentos/fundos-de-investimento/lista-de-fundos-de-investimento.aspx
    It opens all individual links from the and scrap historical data and detailed information from funds.

    Parameters
    ----------
    codes : pandas.Series
        Holds the funds referece codes on the XP platform.
    infos : pandas.Series
        Holds a binary information for each fund that indicates if it has historical data (1) or not (0).
    
    Returns
    -------
    df_deep : pandas.DataFrame
        All detailed data from funds, including historical informaiton if available.
    
    """ 
    options = webdriver.ChromeOptions()
    options.add_argument("safebrowsing-disable-extension-blacklist")
    options.add_argument("--headless")
    driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver.exe')
    
    total_rows = len(list(codes))
    start_time = time.time()
    funds = []
    for i, (code, info01) in enumerate(zip(codes, infos01)):
        d = {}
        #if i % 10 == 0:
        print(code)
        #print('Progress(%)', (i/len(list_funds))*100)
        
        
        driver.get('https://institucional.xpi.com.br/investimentos/fundos-de-investimento/detalhes-de-fundos-de-investimento.aspx?F='+str(code))
        try:
            WebDriverWait(driver, 10).until(
                EC.presence_of_element_located(
                    (By.XPATH, "//table[@class='table table-bordered table-hover tabelaXP']/tbody/tr/td"))
            )
        finally:
            #infos = driver.find_elements_by_xpath("//table[@class='table table-bordered table-hover tabelaXP']/tbody/tr/td")
            #fund_dict['Data'] = infos[0].text
            #fund_dict['Cota'] = infos[1].text.replace(',', '.')
            
            #if fund_dict['Info'] == 1:
            #    fund_dict['Rent. dia'] = infos[2].text[:-1].replace(',', '.')
            #    fund_dict['PL atual (R$)'] = infos[6].text[2:].replace('.', '').replace(',', '.')
            #    fund_dict['PL medio anual (R$)'] = infos[7].text[2:].replace('.', '').replace(',', '.')
            #else:
            #    fund_dict['Rent. dia'] = np.nan
            #    fund_dict['PL atual (R$)'] = np.nan
            #    fund_dict['PL medio anual (R$)'] = np.nan
            
            driver.find_element_by_xpath("//a[text()='Características do Fundo']").click()
            try:
                WebDriverWait(driver, 10).until(
                    EC.presence_of_element_located(
                        (By.XPATH, "//div[@class='tab-pane fade active in']/table/tbody/tr[1]/td[2]/h4"))
                )
            finally:
                d['Inicio'] = driver.find_element_by_xpath("//div[@class='tab-pane fade active in']/table/tbody/tr[1]/td[2]/h4").text
                #if fund_dict['Info'] == 0: # another source of getting PL info if N/D data
                d['PL atual (R$)'] = driver.find_element_by_xpath("//div[@class='tab-pane fade active in']/table/tbody/tr[2]/td[2]/h4/span").text.replace('.', '').replace(',', '.')
                d['PL medio anual (R$)'] = driver.find_element_by_xpath("//div[@class='tab-pane fade active in']/table/tbody/tr[3]/td[2]/h4/span").text.replace('.', '').replace(',', '.')
                d['Objetivos'] = driver.find_element_by_xpath("//strong[text()='Objetivos']/ancestor::p/following-sibling::p").text.strip()
                d['Publico-alvo'] = driver.find_element_by_xpath("//strong[text()='Público-alvo']/ancestor::p/following-sibling::p").text.strip()
                d['Politica de gestao'] = driver.find_element_by_xpath("//strong[text()='Política de gestão']/ancestor::p/following-sibling::p").text.strip()
                
                files = driver.find_elements_by_xpath("//div[@id='dvArqsDownload']/div")
                links = {}
                for file in files:
                    link = file.find_element_by_xpath(".//p/a").get_attribute('href')
                    name = file.find_element_by_xpath(".//p/a").get_attribute('id')
                    links[name] = link
                d['Links'] = links
                
                driver.find_element_by_xpath("//a[text()='Informações complementares']").click()
                try:
                    WebDriverWait(driver, 10).until(
                        EC.presence_of_element_located(
                            (By.XPATH, "//td[starts-with(text(), 'Aplicação Inicial Mínima')]"))
                    )
                finally:
                    d['Aplicação Inicial Mínima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Aplicação Inicial Mínima')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
                    d['Movimentação Mínima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Movimentação Mínima')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
                    d['Saldo de Permanência'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Saldo de Permanência')]/following-sibling::td").text[2:].strip().replace('.', '').replace(',', '.')
                    d['Taxa de Administração'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa de Administração')]/following-sibling::td").text[:-1].replace(',', '.')
                    d['Taxa Máxima de Administração'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa Máxima de Administração')]/following-sibling::td").text[:-4].replace(',', '.')
                    d['Taxa de Performance'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Taxa de Performance')]/following-sibling::td").text.strip()
                    d['Tributação'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Tributação')]/following-sibling::td").text.strip()
                    d['IOF'] = driver.find_element_by_xpath("//td[starts-with(text(), 'IOF')]/following-sibling::td").text.strip()
                    d['Aplicação'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Aplicação\n')]/following-sibling::td").text.strip()
                    d['Resgate - Cotização'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Resgate - Cotização')]/following-sibling::td").text.strip()
                    d['Resgate - Liquidação Financeira'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Resgate - Liquidação Financeira')]/following-sibling::td").text.strip()
                    d['Horário para Aplicação e Resgate'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Horário para Aplicação e Resgate')]/following-sibling::td").text.strip()
                    d['Divulgação de quota e PL'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Divulgação de quota e PL')]/following-sibling::td").text.strip()
                    d['Classificação Anbima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Classificação Anbima')]/following-sibling::td").text.strip()
                    d['Código Anbima'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Código Anbima')]/following-sibling::td").text.strip()
                    d['Custódia'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Custódia')]/following-sibling::td").text.strip()
                    d['Auditoria'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Auditoria')]/following-sibling::td").text.strip()
                    d['Gestor'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Gestor')]/following-sibling::td").text.strip()
                    d['Administrador'] = driver.find_element_by_xpath("//td[starts-with(text(), 'Administrador\n')]/following-sibling::td").text.strip()
                    
                    if info01 == 1:
                        driver.get("https://institucional.xpi.com.br/api/Ranking/GraficoFundo?idFundo={0}&tipo=3".format(code))
                        time.sleep(0.1)
                        soup = BeautifulSoup(driver.page_source)
                        dict_from_json = json.loads(soup.find("body").text)
                        graph = dict_from_json['Fundo']
                        for day in graph:
                            del day['key']
                            day['Date'] = day['Ano'].split('T')[0]
                            del day['Ano']
                        d['Daily profitability'] = pd.DataFrame(graph).set_index('Date')
                    else:
                        d['Daily profitability'] = np.nan
        funds.append(d)
        
        # estimating remaining time
        diff = time.time() - start_time
        avg_time = diff/(i+1)
        estimated_remaning_time = avg_time*(total_rows-(i+1))
        print('Estimated remaining time (min):', estimated_remaning_time/60)
        
    driver.quit() 
    
    now = datetime.datetime.now()
    date = now.strftime("%d-%m-%Y")
    file_name = 'xp_funds_deep'
    with open('{0}_{1}.pickle'.format(file_name, date), 'wb') as handle:
        pickle.dump(pd.DataFrame(funds), handle, protocol=pickle.HIGHEST_PROTOCOL)  
            
    return pd.DataFrame(funds)

# %%
df_deep = deep_data(df_surf['Codigo'], df_surf['Info'])
# Out:
# 800981
# Estimated remaining time (min): 28.129416751861573
# 800868
# Estimated remaining time (min): 23.503977715969086
# 2289
# Estimated remaining time (min): 22.320418294270834
# 2900
# Estimated remaining time (min): 21.664541512727737
# 800441
# Estimated remaining time (min): 20.87072399457296
# 800832
# Estimated remaining time (min): 20.189858568376962
# 2798
# Estimated remaining time (min): 20.083855261121478
# 7455
# Estimated remaining time (min): 19.866573802630107
# 2692
# Estimated remaining time (min): 19.637232709814
# 800590
# Estimated remaining time (min): 19.448500771522518
# 800588
# Estimated remaining time (min): 19.255462106791413
# 3058
# Estimated remaining time (min): 19.11986757583088
# 800817
# Estimated remaining time (min): 18.966872185927173
# 2732
# Estimated remaining time (min): 18.907213906447094
# 2676
# Estimated remaining time (min): 18.802672997580636
# 2149
# Estimated remaining time (min): 18.771623787283897
# 800456
# Estimated remaining time (min): 18.797063993940167
# 800690
# Estimated remaining time (min): 18.823246493604447
# 7436
# Estimated remaining time (min): 18.890808601128427
# 6650
# Estimated remaining time (min): 18.900291284124055
# 2118
# Estimated remaining time (min): 18.81052009037563
# 2748
# Estimated remaining time (min): 18.81174433448098
# 800670
# Estimated remaining time (min): 18.764581022400787
# 2292
# Estimated remaining time (min): 18.64826405296723
# 3247
# Estimated remaining time (min): 18.551618774414063
# 800937
# Estimated remaining time (min): 18.411438223948846
# 2365
# Estimated remaining time (min): 18.34678180983037
# 2971
# Estimated remaining time (min): 18.257330479366438
# 7868
# Estimated remaining time (min): 18.18327701776877
# 800499
# Estimated remaining time (min): 18.13900445765919
# 800958
# Estimated remaining time (min): 17.98438578497979
# 800627
# Estimated remaining time (min): 17.95439224963387
# 2891
# Estimated remaining time (min): 17.936486384844542
# 1963
# Estimated remaining time (min): 17.896173631443695
# 2897
# Estimated remaining time (min): 17.881772456169127
# 800716
# Estimated remaining time (min): 17.829733718876486
# 800572
# Estimated remaining time (min): 17.795913273579362
# 800721
# Estimated remaining time (min): 17.735642500091014
# 800722
# Estimated remaining time (min): 17.680758942905655
# 800680
# Estimated remaining time (min): 17.65617377758026
# 800755
# Estimated remaining time (min): 17.610203125806358
# 800582
# Estimated remaining time (min): 17.53885568910175
# 2656
# Estimated remaining time (min): 17.507677402607232
# 2659
# Estimated remaining time (min): 17.47771688708753
# 800550
# Estimated remaining time (min): 17.422526568306814
# 800593
# Estimated remaining time (min): 17.365370989104974
# 800836
# Estimated remaining time (min): 17.300578869826403
# 2888
# Estimated remaining time (min): 17.25339514977402
# 800700
# Estimated remaining time (min): 17.191644036040014
# 5041
# Estimated remaining time (min): 17.13696442055702
# 800697
# Estimated remaining time (min): 17.145371482263204
# 6505
# Estimated remaining time (min): 17.11364104770697
# 2861
# Estimated remaining time (min): 17.11134393979918
# 2677
# Estimated remaining time (min): 17.066382736335566
# 800442
# Estimated remaining time (min): 17.00271670991724
# 800339
# Estimated remaining time (min): 16.96465181467079
# 800560
# Estimated remaining time (min): 16.97099800332945
# 3663
# Estimated remaining time (min): 16.933558281331226
# 800523
# Estimated remaining time (min): 16.89791198504173
# 800676
# Estimated remaining time (min): 16.882958124876023
# 800599
# Estimated remaining time (min): 16.823831303393256
# 3409
# Estimated remaining time (min): 16.777485804660348
# 6355
# Estimated remaining time (min): 16.72452566459696
# 2832
# Estimated remaining time (min): 16.691178598441184
# 800741
# Estimated remaining time (min): 16.6497783103356
# 800580
# Estimated remaining time (min): 16.637164024090527
# 7456
# Estimated remaining time (min): 16.5801786031296
# 2728
# Estimated remaining time (min): 16.51334739526113
# 800857
# Estimated remaining time (min): 16.453427420722115
# 800924
# Estimated remaining time (min): 16.403743408407482
# 2156
# Estimated remaining time (min): 16.391179630006423
# 92
# Estimated remaining time (min): 16.350446778370276
# 800727
# Estimated remaining time (min): 16.313359986919245
# 800802
# Estimated remaining time (min): 16.266125513895137
# 2733
# Estimated remaining time (min): 16.212759862793817
# 2544
# Estimated remaining time (min): 16.164983693078945
# 2515
# Estimated remaining time (min): 16.159079962065725
# 800734
# Estimated remaining time (min): 16.110105240497834
# 7806
# Estimated remaining time (min): 16.080035672912114
# 6306
# Estimated remaining time (min): 16.038252447098493
# 7130
# Estimated remaining time (min): 15.986333257180672
# 6455
# Estimated remaining time (min): 15.941033298067932
# 800651
# Estimated remaining time (min): 15.879280402765696
# 800957
# Estimated remaining time (min): 15.796393242383761
# 2467
# Estimated remaining time (min): 15.759004033032587
# 2737
# Estimated remaining time (min): 15.705633150514705
# 2412
# Estimated remaining time (min): 15.654918844307064
# 3971
# Estimated remaining time (min): 15.615297202224081
# 28981
# Estimated remaining time (min): 15.556694173634275
# 2912
# Estimated remaining time (min): 15.50604249631917
# 2911
# Estimated remaining time (min): 15.45508090899541
# 800636
# Estimated remaining time (min): 15.403742834277775
# 2903
# Estimated remaining time (min): 15.348130779027084
# 2618
# Estimated remaining time (min): 15.304911241886463
# 2455
# Estimated remaining time (min): 15.255956171186346
# 1480
# Estimated remaining time (min): 15.208235054918463
# 3559
# Estimated remaining time (min): 15.162347864367298
# 2926
# Estimated remaining time (min): 15.122561642061287
# 6086
# Estimated remaining time (min): 15.07527699454465
# 2800
# Estimated remaining time (min): 15.026483597755432
# 800952
# Estimated remaining time (min): 14.957611599220302
# 800610
# Estimated remaining time (min): 14.912412280272813
# 2862
# Estimated remaining time (min): 14.863987011353947
# 800702
# Estimated remaining time (min): 14.823264833826283
# 2813
# Estimated remaining time (min): 14.762667741321382
# 800894
# Estimated remaining time (min): 14.701560905182138
# 2835
# Estimated remaining time (min): 14.664135525382568
# 438
# Estimated remaining time (min): 14.608208692257788
# 2553
# Estimated remaining time (min): 14.55425871621578
# 800831
# Estimated remaining time (min): 14.496237718300387
# 2675
# Estimated remaining time (min): 14.444332747130064
# 800561
# Estimated remaining time (min): 14.396469681284257
# 2109
# Estimated remaining time (min): 14.360549927320452
# 800925
# Estimated remaining time (min): 14.302143643125456
# 2617
# Estimated remaining time (min): 14.260921604322352
# 800765
# Estimated remaining time (min): 14.205228470728315
# 2702
# Estimated remaining time (min): 14.163544405151978
# 1256
# Estimated remaining time (min): 14.122285438291097
# 800564
# Estimated remaining time (min): 14.074167962501695
# 800563
# Estimated remaining time (min): 14.01608956032329
# 2806
# Estimated remaining time (min): 13.97057798086119
# 2705
# Estimated remaining time (min): 13.931075373210543
# 2473
# Estimated remaining time (min): 13.88351095123343
# 2630
# Estimated remaining time (min): 13.833663974558155
# 2594
# Estimated remaining time (min): 13.7905589747111
# 2750
# Estimated remaining time (min): 13.742210503450776
# 800756
# Estimated remaining time (min): 13.686576657032402
# 800578
# Estimated remaining time (min): 13.646836344432085
# 6523
# Estimated remaining time (min): 13.59238762202497
# 2807
# Estimated remaining time (min): 13.550144769870318
# 800866
# Estimated remaining time (min): 13.49403035270652
# 2935
# Estimated remaining time (min): 13.470266446320696
# 800592
# Estimated remaining time (min): 13.421012068870372
# 800822
# Estimated remaining time (min): 13.363831700080661
# 2930
# Estimated remaining time (min): 13.309542555338071
# 2834
# Estimated remaining time (min): 13.258177782945774
# 800638
# Estimated remaining time (min): 13.203467902301872
# 800667
# Estimated remaining time (min): 13.160187500254544
# 525
# Estimated remaining time (min): 13.113553530878301
# 800618
# Estimated remaining time (min): 13.069945512357213
# 800922
# Estimated remaining time (min): 13.014182627003809
# 800624
# Estimated remaining time (min): 12.959507897454248
# 800888
# Estimated remaining time (min): 12.907086848601317
# 2914
# Estimated remaining time (min): 12.850663393735886
# 2305
# Estimated remaining time (min): 12.79691555483588
# 800479
# Estimated remaining time (min): 12.747927440519202
# 800754
# Estimated remaining time (min): 12.694656089428062
# 800758
# Estimated remaining time (min): 12.648533712367755
# 800935
# Estimated remaining time (min): 12.595396746458357
# 800457
# Estimated remaining time (min): 12.540329797506331
# 6006
# Estimated remaining time (min): 12.492647225019947
# 6111
# Estimated remaining time (min): 12.44177602103405
# 800801
# Estimated remaining time (min): 12.390408105787888
# 800574
# Estimated remaining time (min): 12.345887341669627
# 800959
# Estimated remaining time (min): 12.284398798429837
# 800691
# Estimated remaining time (min): 12.231707531901508
# 1017
# Estimated remaining time (min): 12.183392095869515
# 50110
# Estimated remaining time (min): 12.13560723896268
# 27744
# Estimated remaining time (min): 12.083773924119816
# 800757
# Estimated remaining time (min): 12.033940739557147
# 800634
# Estimated remaining time (min): 11.982488010240639
# 800767
# Estimated remaining time (min): 11.930191571158145
# 2886
# Estimated remaining time (min): 11.891619169785201
# 27901
# Estimated remaining time (min): 11.85161999098169
# 800696
# Estimated remaining time (min): 11.824185491330697
# 800740
# Estimated remaining time (min): 11.770221547908092
# 800480
# Estimated remaining time (min): 11.717302535346407
# 2901
# Estimated remaining time (min): 11.669106132383384
# 2684
# Estimated remaining time (min): 11.619331009994598
# 2747
# Estimated remaining time (min): 11.574437343630136
# 800695
# Estimated remaining time (min): 11.522849607421175
# 2917
# Estimated remaining time (min): 11.470241160517514
# 2803
# Estimated remaining time (min): 11.419421166124142
# 800591
# Estimated remaining time (min): 11.365348281188943
# 800496
# Estimated remaining time (min): 11.31328355721065
# 800586
# Estimated remaining time (min): 11.264651874317364
# 800784
# Estimated remaining time (min): 11.211494035954304
# 2839
# Estimated remaining time (min): 11.167883109577586
# 801106
# Estimated remaining time (min): 11.118784626324972
# 800738
# Estimated remaining time (min): 11.10776849925518
# 800739
# Estimated remaining time (min): 11.064421056515604
# 800472
# Estimated remaining time (min): 11.016969059828
# 2955
# Estimated remaining time (min): 10.971274836858113
# 801114
# Estimated remaining time (min): 10.91582368573417
# 6488
# Estimated remaining time (min): 10.881792036176801
# 800984
# Estimated remaining time (min): 10.84098244993063
# 800885
# Estimated remaining time (min): 10.79151812288213
# 800575
# Estimated remaining time (min): 10.742473361276565
# 6060
# Estimated remaining time (min): 10.696522065150884
# 2745
# Estimated remaining time (min): 10.64827609181404
# 800968
# Estimated remaining time (min): 10.598287931037822
# 800632
# Estimated remaining time (min): 10.558016983874971
# 2885
# Estimated remaining time (min): 10.511732474015785
# 2765
# Estimated remaining time (min): 10.461287681179765
# 12345
# Estimated remaining time (min): 10.417222552829319
# 800600
# Estimated remaining time (min): 10.365798140058711
# 800886
# Estimated remaining time (min): 10.314058560405284
# 2805
# Estimated remaining time (min): 10.361908115722516
# 801110
# Estimated remaining time (min): 10.308674215072363
# 800987
# Estimated remaining time (min): 10.254829508622489
# 800640
# Estimated remaining time (min): 10.203768532153584
# 800568
# Estimated remaining time (min): 10.150274476084379
# 800985
# Estimated remaining time (min): 10.098687685730031
# 2138
# Estimated remaining time (min): 10.065033834451944
# 801117
# Estimated remaining time (min): 10.018370274101814
# 800896
# Estimated remaining time (min): 10.009367112260806
# 801120
# Estimated remaining time (min): 9.98024490347999
# 801122
# Estimated remaining time (min): 9.926132456729047
# 801124
# Estimated remaining time (min): 9.884358182478179
# 800862
# Estimated remaining time (min): 9.837987644123652
# 2823
# Estimated remaining time (min): 9.792095158111428
# 2822
# Estimated remaining time (min): 9.739787083114468
# 2931
# Estimated remaining time (min): 9.693806349988648
# 29431
# Estimated remaining time (min): 9.640335378802826
# 800701
# Estimated remaining time (min): 9.594712421838627
# 801108
# Estimated remaining time (min): 9.546221252374442
# 800598
# Estimated remaining time (min): 9.499861232915782
# 2707
# Estimated remaining time (min): 9.448657164934579
# 7670
# Estimated remaining time (min): 9.400721784414584
# 7934
# Estimated remaining time (min): 9.348720980449155
# 3563
# Estimated remaining time (min): 9.295575835514212
# 2719
# Estimated remaining time (min): 9.24679724903436
# 800737
# Estimated remaining time (min): 9.203493170032585
# 2650
# Estimated remaining time (min): 9.155876941091957
# 800576
# Estimated remaining time (min): 9.108958401574029
# 800889
# Estimated remaining time (min): 9.057102923477645
# 6787
# Estimated remaining time (min): 9.009135787707594
# 800769
# Estimated remaining time (min): 8.954813877880921
# 75
# Estimated remaining time (min): 8.902954904273088
# 2938
# Estimated remaining time (min): 8.853847315484199
# 2693
# Estimated remaining time (min): 8.805782037723977
# 801102
# Estimated remaining time (min): 8.757132469220409
# 800919
# Estimated remaining time (min): 8.705322472459086
# 800920
# Estimated remaining time (min): 8.652266567503965
# 800921
# Estimated remaining time (min): 8.602553648948668
# 1633
# Estimated remaining time (min): 8.55352235352252
# 2932
# Estimated remaining time (min): 8.500980643246915
# 2402
# Estimated remaining time (min): 8.449115884354136
# 6382
# Estimated remaining time (min): 8.396558940992527
# 800556
# Estimated remaining time (min): 8.344656355248556
# 800945
# Estimated remaining time (min): 8.288966579358114
# 3932
# Estimated remaining time (min): 8.23732230059043
# 2418
# Estimated remaining time (min): 8.189365361453083
# 2377
# Estimated remaining time (min): 8.137916999273612
# 2933
# Estimated remaining time (min): 8.084746837226712
# 800869
# Estimated remaining time (min): 8.035246287629533
# 800890
# Estimated remaining time (min): 7.981560832575748
# 2505
# Estimated remaining time (min): 7.930317270307131
# 2724
# Estimated remaining time (min): 7.880907970259946
# 800845
# Estimated remaining time (min): 7.826571668624878
# 800725
# Estimated remaining time (min): 7.773609328966534
# 801090
# Estimated remaining time (min): 7.718665201481057
# 800559
# Estimated remaining time (min): 7.668429407866105
# 3565
# Estimated remaining time (min): 7.619152671474171
# 800897
# Estimated remaining time (min): 7.566304491485645
# 2902
# Estimated remaining time (min): 7.516337047051638
# 800764
# Estimated remaining time (min): 7.464652099436205
# 800776
# Estimated remaining time (min): 7.413743860931051
# 800584
# Estimated remaining time (min): 7.36187617751162
# 800516
# Estimated remaining time (min): 7.312884480204338
# 800979
# Estimated remaining time (min): 7.265073384970693
# 3702
# Estimated remaining time (min): 7.215327507302961
# 2679
# Estimated remaining time (min): 7.164513475057896
# 2654
# Estimated remaining time (min): 7.1137130116724006
# 2645
# Estimated remaining time (min): 7.063559825825242
# 2716
# Estimated remaining time (min): 7.012754602629439
# 800672
# Estimated remaining time (min): 6.963963690560111
# 2824
# Estimated remaining time (min): 6.913270894582592
# 3716
# Estimated remaining time (min): 6.863497555329749
# 801051
# Estimated remaining time (min): 6.816060617970831
# 800865
# Estimated remaining time (min): 6.766465520154947
# 2764
# Estimated remaining time (min): 6.716220922636635
# 800608
# Estimated remaining time (min): 6.6644842231666654
# 2880
# Estimated remaining time (min): 6.614953479845158
# 800510
# Estimated remaining time (min): 6.564179135091377
# 801063
# Estimated remaining time (min): 6.512617689457492
# 800871
# Estimated remaining time (min): 6.460210364131721
# 2503
# Estimated remaining time (min): 6.410134610140639
# 2940
# Estimated remaining time (min): 6.358330774763009
# 2597
# Estimated remaining time (min): 6.3077885477883475
# 800468
# Estimated remaining time (min): 6.256570792961799
# 2870
# Estimated remaining time (min): 6.2061469341846225
# 800864
# Estimated remaining time (min): 6.154252161491043
# 1974
# Estimated remaining time (min): 6.103765315642938
# 1972
# Estimated remaining time (min): 6.054342352660776
# 2603
# Estimated remaining time (min): 6.003298333891622
# 800532
# Estimated remaining time (min): 5.953046732330987
# 801098
# Estimated remaining time (min): 5.900400088244567
# 801085
# Estimated remaining time (min): 5.850164017462813
# 2782
# Estimated remaining time (min): 5.800308098272345
# 800841
# Estimated remaining time (min): 5.75090928836923
# 800800
# Estimated remaining time (min): 5.700159102637474
# 2738
# Estimated remaining time (min): 5.651129119632187
# 800557
# Estimated remaining time (min): 5.600590225452739
# 800860
# Estimated remaining time (min): 5.551108429795605
# 2974
# Estimated remaining time (min): 5.502122810174217
# 800466
# Estimated remaining time (min): 5.452606476677789
# 800495
# Estimated remaining time (min): 5.403983961935811
# 2883
# Estimated remaining time (min): 5.3577434073058
# 800509
# Estimated remaining time (min): 5.308274886714088
# 800682
# Estimated remaining time (min): 5.258343149736474
# 800946
# Estimated remaining time (min): 5.207246310347753
# 2890
# Estimated remaining time (min): 5.157591977869585
# 800674
# Estimated remaining time (min): 5.106982602296691
# 800878
# Estimated remaining time (min): 5.056058481664606
# 800911
# Estimated remaining time (min): 5.005645714203516
# 2635
# Estimated remaining time (min): 4.955650556592289
# 2718
# Estimated remaining time (min): 4.905824512398088
# 800692
# Estimated remaining time (min): 4.856383679625543
# 28761
# Estimated remaining time (min): 4.806394129491622
# 800780
# Estimated remaining time (min): 4.75629637990095
# 3585
# Estimated remaining time (min): 4.707128191720217
# 7012
# Estimated remaining time (min): 4.658567295744777
# 800934
# Estimated remaining time (min): 4.60712314835273
# 800753
# Estimated remaining time (min): 4.5571482445954015
# 7494
# Estimated remaining time (min): 4.509346237967285
# 6120
# Estimated remaining time (min): 4.460567208469603
# 2313
# Estimated remaining time (min): 4.411845924931752
# 2877
# Estimated remaining time (min): 4.362767742719023
# 2874
# Estimated remaining time (min): 4.31352051862826
# 2369
# Estimated remaining time (min): 4.265655290993823
# 800768
# Estimated remaining time (min): 4.215497896686104
# 800607
# Estimated remaining time (min): 4.166073074773862
# 800476
# Estimated remaining time (min): 4.117021448389003
# 2657
# Estimated remaining time (min): 4.069230645693265
# 2942
# Estimated remaining time (min): 4.020948076760111
# 801105
# Estimated remaining time (min): 3.9720423675093812
# 801123
# Estimated remaining time (min): 3.9236133786599807
# 800652
# Estimated remaining time (min): 3.8739426805134847
# 800974
# Estimated remaining time (min): 3.823497078454856
# 800879
# Estimated remaining time (min): 3.773857924873375
# 800910
# Estimated remaining time (min): 3.724661549147832
# 800611
# Estimated remaining time (min): 3.6752993703007824
# 2727
# Estimated remaining time (min): 3.6262129737945377
# 800730
# Estimated remaining time (min): 3.576782070155167
# 2889
# Estimated remaining time (min): 3.5276084123268014
# 2920
# Estimated remaining time (min): 3.4796269538494533
# 2344
# Estimated remaining time (min): 3.4310360041243086
# 800745
# Estimated remaining time (min): 3.381641367778197
# 2647
# Estimated remaining time (min): 3.332467894764507
# 2461
# Estimated remaining time (min): 3.2834355111462394
# 27511
# Estimated remaining time (min): 3.2346480525376506
# 800531
# Estimated remaining time (min): 3.1854858580553147
# 7132
# Estimated remaining time (min): 3.1366822560743772
# 2202
# Estimated remaining time (min): 3.088529458898277
# 800942
# Estimated remaining time (min): 3.039605322083986
# 800762
# Estimated remaining time (min): 2.9907830655632055
# 2722
# Estimated remaining time (min): 2.9428483972946804
# 2884
# Estimated remaining time (min): 2.894193037874719
# 800609
# Estimated remaining time (min): 2.8461082753113343
# 800926
# Estimated remaining time (min): 2.7976473480887565
# 801062
# Estimated remaining time (min): 2.748278253559362
# 800626
# Estimated remaining time (min): 2.704366233778855
# 800565
# Estimated remaining time (min): 2.656221122840479
# 801061
# Estimated remaining time (min): 2.6074793285719107
# 801119
# Estimated remaining time (min): 2.5587415451414133
# 800567
# Estimated remaining time (min): 2.509804474628495
# 801043
# Estimated remaining time (min): 2.4607349334815356
# 800678
# Estimated remaining time (min): 2.4121116949876593
# 800619
# Estimated remaining time (min): 2.3634171631380365
# 800724
# Estimated remaining time (min): 2.314697704685032
# 800723
# Estimated remaining time (min): 2.265884282257456
# 800566
# Estimated remaining time (min): 2.2175691931481967
# 801087
# Estimated remaining time (min): 2.168410990755637
# 800909
# Estimated remaining time (min): 2.119993784917544
# 8032
# Estimated remaining time (min): 2.071538918819584
# 800625
# Estimated remaining time (min): 2.022745019993275
# 800973
# Estimated remaining time (min): 1.9736490627129872
# 800760
# Estimated remaining time (min): 1.9268442341736445
# 800883
# Estimated remaining time (min): 1.878860742659182
# 800882
# Estimated remaining time (min): 1.8304719809251977
# 2893
# Estimated remaining time (min): 1.78210918735646
# 800733
# Estimated remaining time (min): 1.733384455177164
# 2762
# Estimated remaining time (min): 1.6850571977688455
# 800967
# Estimated remaining time (min): 1.6363320527182688
# 2909
# Estimated remaining time (min): 1.588164848659901
# 2653
# Estimated remaining time (min): 1.5399868928890752
# 800558
# Estimated remaining time (min): 1.4917858310687688
# 2740
# Estimated remaining time (min): 1.4440954288266263
# 2944
# Estimated remaining time (min): 1.3956007231850371
# 800645
# Estimated remaining time (min): 1.3475507060373861
# 2918
# Estimated remaining time (min): 1.299307334017379
# 800554
# Estimated remaining time (min): 1.2510851384661734
# 800631
# Estimated remaining time (min): 1.203000131321864
# 2476
# Estimated remaining time (min): 1.1547025576504795
# 800943
# Estimated remaining time (min): 1.106080333185937
# 800944
# Estimated remaining time (min): 1.0576789903599677
# 2642
# Estimated remaining time (min): 1.0097322784748275
# 2593
# Estimated remaining time (min): 0.9616367592194597
# 2591
# Estimated remaining time (min): 0.9134274703111404
# 800497
# Estimated remaining time (min): 0.865777549841215
# 2729
# Estimated remaining time (min): 0.8174934930845994
# 2924
# Estimated remaining time (min): 0.7692709197221518
# 2019
# Estimated remaining time (min): 0.721007437119024
# 6876
# Estimated remaining time (min): 0.6729273070564753
# 2799
# Estimated remaining time (min): 0.6249874677320923
# 1840
# Estimated remaining time (min): 0.5771336396935605
# 2753
# Estimated remaining time (min): 0.5289598013787613
# 800526
# Estimated remaining time (min): 0.48079926019523583
# 800962
# Estimated remaining time (min): 0.4325524949133397
# 800852
# Estimated remaining time (min): 0.3844346345313271
# 800478
# Estimated remaining time (min): 0.33634689873328455
# 800839
# Estimated remaining time (min): 0.28819920046453734
# 801031
# Estimated remaining time (min): 0.24010984983184552
# 801034
# Estimated remaining time (min): 0.19205526650197222
# 800644
# Estimated remaining time (min): 0.1440201731150961
# 801050
# Estimated remaining time (min): 0.09597500206309201
# 801121
# Estimated remaining time (min): 0.04797016732832964
# 800986
# Estimated remaining time (min): 0.0

# %%
getsizeof(df_deep)/1000000 # size in MBs
# Out:
# 18.181227
